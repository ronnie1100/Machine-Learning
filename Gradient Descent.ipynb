# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

# %%
data = pd.read_csv("Transformed_Housing_Data2.csv")
data
# Out:
#        Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0        221900.0               3             1.00               1180.0
# 1        538000.0               3             2.25               2570.0
# 2        180000.0               2             1.00                770.0
# 3        604000.0               4             3.00               1960.0
# 4        510000.0               3             2.00               1680.0
# ...           ...             ...              ...                  ...
# 21604    360000.0               3             2.50               1530.0
# 21605    400000.0               4             2.50               2310.0
# 21606    402101.0               2             0.75               1020.0
# 21607    400000.0               3             2.50               1600.0
# 21608    325000.0               2             0.75               1020.0
#
#        Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# ...

# %%
sale_price = data['Sale_Price'].head(40)
flat_area = data['Flat Area (in Sqft)'].head(40)
sample_data = pd.DataFrame({'sale_price' : sale_price , 'flat_area':flat_area})
sample_data
# Out:
#     sale_price  flat_area
# 0     221900.0     1180.0
# 1     538000.0     2570.0
# 2     180000.0      770.0
# 3     604000.0     1960.0
# 4     510000.0     1680.0
# 5    1129575.0     5420.0
# 6     257500.0     1715.0
# 7     291850.0     1060.0
# 8     229500.0     1780.0
# 9     323000.0     1890.0
# 10    662500.0     3560.0
# 11    468000.0     1160.0
# 12    310000.0     1430.0
# 13    400000.0     1370.0
# 14    530000.0     1810.0
# 15    650000.0     2950.0
# 16    395000.0     1890.0
# 17    485000.0     1600.0
# 18    189000.0     1200.0
# 19    230000.0     1250.0
# 20    385000.0     1620.0
# 21   1129575.0     3050.0
# 22    285000.0     2270.0
# 23    252700.0     1070.0
# 24    329000.0     2450.0
# 25    233000.0     1710.0
# 26    937000.0     2450.0
# 27    667000.0     1400.0
# 28    438000.0     1520.0
# 29    719000.0     2570.0
# 30    580500.0     2320.0
# 31    280000.0     1190.0
# 32    687500.0     2330.0
# 33    535000.0     1090.0
# ...

# %%
plt.figure(dpi = 120)
plt.scatter(sample_data.flat_area , sample_data.sale_price , color = 'blue' , label = 'sale_price')
plt.xlabel("flat_area")
plt.ylabel("sale_price")
plt.show()

# %%
sample_data_mean = sample_data('sale_price').mean
plt.figure(dpi = 120)
plt.scatter(sample_data.flat_area , sample_data.sale_price , color = 'blue' , label = "Sale price")
plt.plot(sample_data.flat_area , sample_data_mean , color = 'red' , label = '')
